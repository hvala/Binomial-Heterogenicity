# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_binhet = pd.read_csv("totalHet.txt")

# %%
sns.distplot(df_binhet['100'])
plt.xlim=(0,500)

# %%
sns.distplot(df_binhet['200'])

# %%
sns.distplot(df_binhet['300'])

# %%
sns.distplot(df_binhet['400'])

# %%
sns.distplot(df_binhet['500'])

# %%
sns.distplot(df_binhet['600'])

# %%
sns.distplot(df_binhet['700'])

# %%
sns.distplot(df_binhet['800'])

# %%
sns.distplot(df_binhet['900'])

# %%
sns.distplot(df_binhet['1000'])
